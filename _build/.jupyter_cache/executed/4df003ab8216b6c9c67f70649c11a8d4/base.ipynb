# %%
library(tidyverse) 

library(here)

load(
  here("data", "cmhflights_01092017.RData")
  )
# Out:
# ── Attaching packages ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.1 ──
# ✔ ggplot2 3.3.5     ✔ purrr   0.3.4
# ✔ tibble  3.1.6     ✔ dplyr   1.0.7
# ✔ tidyr   1.1.4     ✔ stringr 1.4.0
# ✔ readr   2.1.1     ✔ forcats 0.5.1
# ── Conflicts ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# here() starts at /Users/ruhil/Documents/github/my-jbooks/mynewbook/docs

# %%
dim(cmhflights)

names(cmhflights) # will show you the column names
# Out:
# [1] 35993   110
#   [1] "Year"                 "Quarter"              "Month"
#   [4] "DayofMonth"           "DayOfWeek"            "FlightDate"
#   [7] "UniqueCarrier"        "AirlineID"            "Carrier"
#  [10] "TailNum"              "FlightNum"            "OriginAirportID"
#  [13] "OriginAirportSeqID"   "OriginCityMarketID"   "Origin"
#  [16] "OriginCityName"       "OriginState"          "OriginStateFips"
#  [19] "OriginStateName"      "OriginWac"            "DestAirportID"
#  [22] "DestAirportSeqID"     "DestCityMarketID"     "Dest"
#  [25] "DestCityName"         "DestState"            "DestStateFips"
#  [28] "DestStateName"        "DestWac"              "CRSDepTime"
#  [31] "DepTime"              "DepDelay"             "DepDelayMinutes"
#  [34] "DepDel15"             "DepartureDelayGroups" "DepTimeBlk"
#  [37] "TaxiOut"              "WheelsOff"            "WheelsOn"
#  [40] "TaxiIn"               "CRSArrTime"           "ArrTime"
#  [43] "ArrDelay"             "ArrDelayMinutes"      "ArrDel15"
#  [46] "ArrivalDelayGroups"   "ArrTimeBlk"           "Cancelled"
#  [49] "CancellationCode"     "Diverted"             "CRSElapsedTime"
#  [52] "ActualElapsedTime"    "AirTime"              "Flights"
#  [55] "Distance"             "DistanceGroup"        "CarrierDelay"
#  [58] "WeatherDelay"         "NASDelay"             "SecurityDelay"
#  [61] "LateAircraftDelay"    "FirstDepTime"         "TotalAddGTime"
#  [64] "LongestAddGTime"      "DivAirportLandings"   "DivReachedDest"
#  [67] "DivActualElapsedTime" "DivArrDelay"          "DivDistance"
#  [70] "Div1Airport"          "Div1AirportID"        "Div1AirportSeqID"
#  [73] "Div1WheelsOn"         "Div1TotalGTime"       "Div1LongestGTime"
#  [76] "Div1WheelsOff"        "Div1TailNum"          "Div2Airport"
#  [79] "Div2AirportID"        "Div2AirportSeqID"     "Div2WheelsOn"
#  [82] "Div2TotalGTime"       "Div2LongestGTime"     "Div2WheelsOff"
#  [85] "Div2TailNum"          "Div3Airport"          "Div3AirportID"
#  [88] "Div3AirportSeqID"     "Div3WheelsOn"         "Div3TotalGTime"
#  [91] "Div3LongestGTime"     "Div3WheelsOff"        "Div3TailNum"
#  [94] "Div4Airport"          "Div4AirportID"        "Div4AirportSeqID"
#  [97] "Div4WheelsOn"         "Div4TotalGTime"       "Div4LongestGTime"
# [100] "Div4WheelsOff"        "Div4TailNum"          "Div5Airport"
# [103] "Div5AirportID"        "Div5AirportSeqID"     "Div5WheelsOn"
# [106] "Div5TotalGTime"       "Div5LongestGTime"     "Div5WheelsOff"
# [109] "Div5TailNum"          "X110"

# %%
cmhflights$X110 <- NULL #This command will delete the column named X110

# %%
names(cmhflights)
# Out:
#   [1] "Year"                 "Quarter"              "Month"
#   [4] "DayofMonth"           "DayOfWeek"            "FlightDate"
#   [7] "UniqueCarrier"        "AirlineID"            "Carrier"
#  [10] "TailNum"              "FlightNum"            "OriginAirportID"
#  [13] "OriginAirportSeqID"   "OriginCityMarketID"   "Origin"
#  [16] "OriginCityName"       "OriginState"          "OriginStateFips"
#  [19] "OriginStateName"      "OriginWac"            "DestAirportID"
#  [22] "DestAirportSeqID"     "DestCityMarketID"     "Dest"
#  [25] "DestCityName"         "DestState"            "DestStateFips"
#  [28] "DestStateName"        "DestWac"              "CRSDepTime"
#  [31] "DepTime"              "DepDelay"             "DepDelayMinutes"
#  [34] "DepDel15"             "DepartureDelayGroups" "DepTimeBlk"
#  [37] "TaxiOut"              "WheelsOff"            "WheelsOn"
#  [40] "TaxiIn"               "CRSArrTime"           "ArrTime"
#  [43] "ArrDelay"             "ArrDelayMinutes"      "ArrDel15"
#  [46] "ArrivalDelayGroups"   "ArrTimeBlk"           "Cancelled"
#  [49] "CancellationCode"     "Diverted"             "CRSElapsedTime"
#  [52] "ActualElapsedTime"    "AirTime"              "Flights"
#  [55] "Distance"             "DistanceGroup"        "CarrierDelay"
#  [58] "WeatherDelay"         "NASDelay"             "SecurityDelay"
#  [61] "LateAircraftDelay"    "FirstDepTime"         "TotalAddGTime"
#  [64] "LongestAddGTime"      "DivAirportLandings"   "DivReachedDest"
#  [67] "DivActualElapsedTime" "DivArrDelay"          "DivDistance"
#  [70] "Div1Airport"          "Div1AirportID"        "Div1AirportSeqID"
#  [73] "Div1WheelsOn"         "Div1TotalGTime"       "Div1LongestGTime"
#  [76] "Div1WheelsOff"        "Div1TailNum"          "Div2Airport"
#  [79] "Div2AirportID"        "Div2AirportSeqID"     "Div2WheelsOn"
#  [82] "Div2TotalGTime"       "Div2LongestGTime"     "Div2WheelsOff"
#  [85] "Div2TailNum"          "Div3Airport"          "Div3AirportID"
#  [88] "Div3AirportSeqID"     "Div3WheelsOn"         "Div3TotalGTime"
#  [91] "Div3LongestGTime"     "Div3WheelsOff"        "Div3TailNum"
#  [94] "Div4Airport"          "Div4AirportID"        "Div4AirportSeqID"
#  [97] "Div4WheelsOn"         "Div4TotalGTime"       "Div4LongestGTime"
# [100] "Div4WheelsOff"        "Div4TailNum"          "Div5Airport"
# [103] "Div5AirportID"        "Div5AirportSeqID"     "Div5WheelsOn"
# [106] "Div5TotalGTime"       "Div5LongestGTime"     "Div5WheelsOff"
# [109] "Div5TailNum"

# %%
cmhflights %>% 
  select(Year:DayOfWeek) -> my.df

# %%
names(my.df)
# Out:
# [1] "Year"       "Quarter"    "Month"      "DayofMonth" "DayOfWeek"

# %%
cmhflights %>%
  select(Year, Quarter, Month, DayofMonth, DayOfWeek) -> my.df 

names(my.df)
# Out:
# [1] "Year"       "Quarter"    "Month"      "DayofMonth" "DayOfWeek"

# %%
cmhflights %>% 
  select(Year, FlightDate:UniqueCarrier, TailNum) -> my.df 

names(my.df)
# Out:
# [1] "Year"          "FlightDate"    "UniqueCarrier" "TailNum"

# %%
cmhflights %>% 
  select(c(1, 3, 5, 7)) -> my.df 

names(my.df)
# Out:
# [1] "Year"          "Month"         "DayOfWeek"     "UniqueCarrier"

# %%
cmhflights %>% 
  select(c(1:5)) -> my.df 

names(my.df)
# Out:
# [1] "Year"       "Quarter"    "Month"      "DayofMonth" "DayOfWeek"

# %%
cmhflights %>% 
  select(c(1, 6:9, 12)) -> my.df

names(my.df)
# Out:
# [1] "Year"            "FlightDate"      "UniqueCarrier"   "AirlineID"
# [5] "Carrier"         "OriginAirportID"

# %%
cmhflights %>% 
  select(contains("Carrier")) -> my.df

names(my.df)
# Out:
# [1] "UniqueCarrier" "Carrier"       "CarrierDelay"

# %%
cmhflights %>% 
  select(starts_with("De")) -> my.df

names(my.df)
# Out:
#  [1] "DestAirportID"        "DestAirportSeqID"     "DestCityMarketID"
#  [4] "Dest"                 "DestCityName"         "DestState"
#  [7] "DestStateFips"        "DestStateName"        "DestWac"
# [10] "DepTime"              "DepDelay"             "DepDelayMinutes"
# [13] "DepDel15"             "DepartureDelayGroups" "DepTimeBlk"

# %%
cmhflights %>% 
  select(ends_with("Num")) -> my.df

names(my.df)
# Out:
# [1] "TailNum"     "FlightNum"   "Div1TailNum" "Div2TailNum" "Div3TailNum"
# [6] "Div4TailNum" "Div5TailNum"

# %%
cmhflights %>%
    select(matches("el")) -> my.df

names(my.df)
# Out:
#  [1] "DepDelay"             "DepDelayMinutes"      "DepDel15"
#  [4] "DepartureDelayGroups" "WheelsOff"            "WheelsOn"
#  [7] "ArrDelay"             "ArrDelayMinutes"      "ArrDel15"
# [10] "ArrivalDelayGroups"   "Cancelled"            "CancellationCode"
# [13] "CRSElapsedTime"       "ActualElapsedTime"    "CarrierDelay"
# [16] "WeatherDelay"         "NASDelay"             "SecurityDelay"
# [19] "LateAircraftDelay"    "DivActualElapsedTime" "DivArrDelay"
# [22] "Div1WheelsOn"         "Div1WheelsOff"        "Div2WheelsOn"
# [25] "Div2WheelsOff"        "Div3WheelsOn"         "Div3WheelsOff"
# [28] "Div4WheelsOn"         "Div4WheelsOff"        "Div5WheelsOn"
# [31] "Div5WheelsOff"

# %%
head(billboard)
# Out:
#   artist       track                   date.entered wk1 wk2 wk3 wk4 wk5 wk6 wk7
# 1 2 Pac        Baby Don't Cry (Keep... 2000-02-26   87  82  72  77  87  94  99
# 2 2Ge+her      The Hardest Part Of ... 2000-09-02   91  87  92  NA  NA  NA  NA
# 3 3 Doors Down Kryptonite              2000-04-08   81  70  68  67  66  57  54
# 4 3 Doors Down Loser                   2000-10-21   76  76  72  69  67  65  55
# 5 504 Boyz     Wobble Wobble           2000-04-15   57  34  25  17  17  31  36
# 6 98^0         Give Me Just One Nig... 2000-08-19   51  39  34  26  26  19   2
#   ⋯ wk67 wk68 wk69 wk70 wk71 wk72 wk73 wk74 wk75 wk76
# 1 ⋯ NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 2 ⋯ NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 3 ⋯ NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 4 ⋯ NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 5 ⋯ NA   NA   NA   NA   NA   NA   NA   NA   NA   NA
# 6 ⋯ NA   NA   NA   NA   NA   NA   NA   NA   NA   NA

# %%
billboard %>%
    select(num_range("wk", 1:5)) -> my.df

names(my.df)
# Out:
# [1] "wk1" "wk2" "wk3" "wk4" "wk5"

# %%
cmhflights %>% 
  filter(Month == 1) -> my.df

table(my.df$Month) # Show me a frequency table for Month in my.df
# Out:
#    1
# 3757

# %%
cmhflights %>% 
  filter(Month == 1, UniqueCarrier == "AA") -> my.df 

table(my.df$Month, my.df$UniqueCarrier) # a simple frequency table
# Out:
#
#      AA
#   1 387

# %%
cmhflights %>% 
  filter(Month == 1, UniqueCarrier == "UA", Dest == "CMH") -> my.df

# %%
cmhflights %>% 
  filter(
    Month %in% c(1, 2), UniqueCarrier == "UA", Dest %in% c("CMH", "ORD")
    ) -> my.df 

table(my.df$Month) # frequency table of Month
# Out:
#   1   2
# 106 145

# %%
table(my.df$UniqueCarrier) # frequency table of UniqueCarrier
# Out:
#  UA
# 251

# %%
table(my.df$Dest) # frequency table of Dest
# Out:
# CMH ORD
# 132 119

# %%
cmhflights %>%
    filter(Month >= 3) -> my.df

table(my.df$Month)
# Out:
#    3    4    5    6    7    8    9
# 4101 4123 4098 4138 4295 4279 3789

# %%
cmhflights %>%
filter(is.na(DepDelay)) -> my.df

summary(my.df$DepDelay)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.    NA's
#      NA      NA      NA     NaN      NA      NA     471

# %%
cmhflights %>% 
    select('Year', 'Month', 'DayofMonth', 'FlightDate', 'Carrier', 'TailNum', 'FlightNum', 
           'Origin', 'OriginCityName', 'Dest', 'DestCityName', 'CRSDepTime', 'DepTime', 
           'DepDelay', 'DepDelayMinutes', 'CRSArrTime', 'ArrTime', 'ArrDelay', 'ArrDelayMinutes') %>%
    filter(Dest %in% c("CMH", "ORD")) -> my.df

my.df %>% 
  arrange(DepDelayMinutes) -> my.df2

my.df2
# Out:
#       Year Month DayofMonth FlightDate Carrier TailNum FlightNum Origin
# 1     2017 1      1         2017-01-01 AA      N802AA  508       LAX
# 2     2017 1      3         2017-01-03 AA      N760AA  508       LAX
# 3     2017 1      4         2017-01-04 AA      N753AA  508       LAX
# 4     2017 1      5         2017-01-05 AA      N744AA  508       LAX
# 5     2017 1      7         2017-01-07 AA      N762AA  508       LAX
# 6     2017 1      8         2017-01-08 AA      N808AA  508       LAX
# 7     2017 1     11         2017-01-11 AA      N756AA  508       LAX
# 8     2017 1     12         2017-01-12 AA      N805AA  508       LAX
# 9     2017 1     13         2017-01-13 AA      N766AA  508       LAX
# 10    2017 1     18         2017-01-18 AA      N825AA  508       LAX
# 11    2017 1     25         2017-01-25 AA      N815AA  508       LAX
# 12    2017 1     26         2017-01-26 AA      N755AA  508       LAX
# 13    2017 1     27         2017-01-27 AA      N834AA  508       LAX
# 14    2017 1     30         2017-01-30 AA      N815AA  508       LAX
# 15    2017 1      1         2017-01-01 AA      N820AA  514       PHX
# 16    2017 1      3         2017-01-03 AA      N742AA  514       PHX
# 17    2017 1     11         2017-01-11 AA      N742AA  514       PHX
# 18    2017 1     12         2017-01-12 AA      N762AA  514       PHX
# 19    2017 1     13         2017-01-13 AA      N822AA  514       PHX
# 20    2017 1     15         2017-01-15 AA      N817AA  514       PHX
# 21    2017 1     16         2017-01-16 AA      N755AA  514       PHX
# 22    2017 1     18         2017-01-18 AA      N840AA  514       PHX
# 23    2017 1     19         2017-01-19 AA      N819AA  514       PHX
# 24    2017 1     22         2017-01-22 AA      N833AA  514       PHX
# 25    2017 1     23         2017-01-23 AA      N760AA  514       PHX
# 26    2017 1     25         2017-01-25 AA      N823AA  514       PHX
# 27    2017 1     26         2017-01-26 AA      N833AA  514       PHX
# 28    2017 1     28         2017-01-28 AA      N755AA  514       PHX
# 29    2017 1     29         2017-01-29 AA      N823AA  514       PHX
# 30    2017 1     30         2017-01-30 AA      N760AA  514       PHX
# ⋮     ⋮    ⋮     ⋮          ⋮          ⋮       ⋮       ⋮         ⋮
# 18770 2017 9     20         2017-09-20 WN      N7726A   494      BWI
# 18771 2017 9     10         2017-09-10 WN      NA      3675      MCO
# 18772 2017 9     10         2017-09-10 WN      NA      4643      MCO
# 18773 2017 9     10         2017-09-10 WN      N8327A  4930      MCO
# 18774 2017 9     10         2017-09-10 WN      N430WN  3714      RSW
# 18775 2017 9     10         2017-09-10 WN      N7818L  4454      TPA
# 18776 2017 9     10         2017-09-10 WN      N915WN  4701      TPA
# 18777 2017 9     11         2017-09-11 WN      N389SW    17      ATL
# 18778 2017 9     11         2017-09-11 WN      N639SW   188      ATL
# 18779 2017 9     11         2017-09-11 WN      N703SW  1816      DEN
# 18780 2017 9     11         2017-09-11 WN      N7878A  1792      MCO
# 18781 2017 9     11         2017-09-11 WN      N248WN  1888      MCO
# 18782 2017 9     11         2017-09-11 WN      N553WN   213      MDW
# 18783 2017 9     20         2017-09-20 WN      N947WN  5861      MDW
# 18784 2017 9      5         2017-09-05 WN      N726SW   494      BWI
# 18785 2017 9     11         2017-09-11 WN      NA       690      RSW
# 18786 2017 9     11         2017-09-11 WN      N484WN   924      TPA
# 18787 2017 9     12         2017-09-12 WN      NA       192      ATL
# 18788 2017 9     12         2017-09-12 WN      NA      1623      DCA
# 18789 2017 9     12         2017-09-12 WN      NA      1792      MCO
# 18790 2017 9     12         2017-09-12 WN      NA       690      RSW
# 18791 2017 9     12         2017-09-12 WN      N426WN   924      TPA
# 18792 2017 9     13         2017-09-13 WN      NA       938      MDW
# 18793 2017 9     13         2017-09-13 WN      NA       690      RSW
# 18794 2017 9     13         2017-09-13 WN      NA       924      TPA
# 18795 2017 9     14         2017-09-14 WN      N240WN   938      MDW
# 18796 2017 9     14         2017-09-14 WN      N430WN  1303      MDW
# 18797 2017 9     14         2017-09-14 WN      N403WN  5861      MDW
# 18798 2017 9     11         2017-09-11 DL      N935DN  1646      ATL
# 18799 2017 9     11         2017-09-11 DL      N921DL  1695      ATL
#       OriginCityName  Dest DestCityName CRSDepTime DepTime DepDelay
# 1     Los Angeles, CA CMH  Columbus, OH 0945       0936     -9
# 2     Los Angeles, CA CMH  Columbus, OH 0945       0939     -6
# 3     Los Angeles, CA CMH  Columbus, OH 0945       0940     -5
# 4     Los Angeles, CA CMH  Columbus, OH 0945       0938     -7
# 5     Los Angeles, CA CMH  Columbus, OH 0945       0941     -4
# 6     Los Angeles, CA CMH  Columbus, OH 0945       0941     -4
# 7     Los Angeles, CA CMH  Columbus, OH 0940       0934     -6
# 8     Los Angeles, CA CMH  Columbus, OH 0940       0935     -5
# 9     Los Angeles, CA CMH  Columbus, OH 0940       0937     -3
# 10    Los Angeles, CA CMH  Columbus, OH 0940       0940      0
# 11    Los Angeles, CA CMH  Columbus, OH 0940       0932     -8
# 12    Los Angeles, CA CMH  Columbus, OH 0940       0935     -5
# 13    Los Angeles, CA CMH  Columbus, OH 0940       0937     -3
# 14    Los Angeles, CA CMH  Columbus, OH 0940       0937     -3
# 15    Phoenix, AZ     CMH  Columbus, OH 1959       1956     -3
# 16    Phoenix, AZ     CMH  Columbus, OH 1959       1955     -4
# 17    Phoenix, AZ     CMH  Columbus, OH 1620       1620      0
# 18    Phoenix, AZ     CMH  Columbus, OH 1620       1617     -3
# 19    Phoenix, AZ     CMH  Columbus, OH 1620       1617     -3
# 20    Phoenix, AZ     CMH  Columbus, OH 1635       1629     -6
# 21    Phoenix, AZ     CMH  Columbus, OH 1620       1614     -6
# 22    Phoenix, AZ     CMH  Columbus, OH 1620       1613     -7
# 23    Phoenix, AZ     CMH  Columbus, OH 1620       1620      0
# 24    Phoenix, AZ     CMH  Columbus, OH 1635       1629     -6
# 25    Phoenix, AZ     CMH  Columbus, OH 1620       1618     -2
# 26    Phoenix, AZ     CMH  Columbus, OH 1620       1614     -6
# 27    Phoenix, AZ     CMH  Columbus, OH 1620       1615     -5
# 28    Phoenix, AZ     CMH  Columbus, OH 1620       1610    -10
# 29    Phoenix, AZ     CMH  Columbus, OH 1635       1633     -2
# 30    Phoenix, AZ     CMH  Columbus, OH 1620       1613     -7
# ⋮     ⋮               ⋮    ⋮            ⋮          ⋮       ⋮
# 18770 Baltimore, MD   CMH  Columbus, OH 1810       NA      NA
# 18771 Orlando, FL     CMH  Columbus, OH 1545       NA      NA
# 18772 Orlando, FL     CMH  Columbus, OH 0910       NA      NA
# 18773 Orlando, FL     CMH  Columbus, OH 2025       NA      NA
# 18774 Fort Myers, FL  CMH  Columbus, OH 1210       NA      NA
# 18775 Tampa, FL       CMH  Columbus, OH 1740       NA      NA
# 18776 Tampa, FL       CMH  Columbus, OH 1055       NA      NA
# 18777 Atlanta, GA     CMH  Columbus, OH 2200       NA      NA
# 18778 Atlanta, GA     CMH  Columbus, OH 1525       NA      NA
# 18779 Denver, CO      CMH  Columbus, OH 1025       NA      NA
# 18780 Orlando, FL     CMH  Columbus, OH 0905       NA      NA
# 18781 Orlando, FL     CMH  Columbus, OH 1640       NA      NA
# 18782 Chicago, IL     CMH  Columbus, OH 1905       NA      NA
# 18783 Chicago, IL     CMH  Columbus, OH 1530       NA      NA
# 18784 Baltimore, MD   CMH  Columbus, OH 1810       NA      NA
# 18785 Fort Myers, FL  CMH  Columbus, OH 1215       NA      NA
# 18786 Tampa, FL       CMH  Columbus, OH 1500       NA      NA
# 18787 Atlanta, GA     CMH  Columbus, OH 0810       NA      NA
# 18788 Washington, DC  CMH  Columbus, OH 1240       NA      NA
# 18789 Orlando, FL     CMH  Columbus, OH 0905       NA      NA
# 18790 Fort Myers, FL  CMH  Columbus, OH 1215       NA      NA
# 18791 Tampa, FL       CMH  Columbus, OH 1500       NA      NA
# 18792 Chicago, IL     CMH  Columbus, OH 1345       NA      NA
# 18793 Fort Myers, FL  CMH  Columbus, OH 1215       NA      NA
# 18794 Tampa, FL       CMH  Columbus, OH 1500       NA      NA
# 18795 Chicago, IL     CMH  Columbus, OH 1345       NA      NA
# 18796 Chicago, IL     CMH  Columbus, OH 1000       NA      NA
# 18797 Chicago, IL     CMH  Columbus, OH 1530       NA      NA
# 18798 Atlanta, GA     CMH  Columbus, OH 1622       NA      NA
# 18799 Atlanta, GA     CMH  Columbus, OH 1430       NA      NA
#       DepDelayMinutes CRSArrTime ArrTime ArrDelay ArrDelayMinutes
# 1     0               1707       1653    -14       0
# 2     0               1707       1630    -37       0
# 3     0               1707       1642    -25       0
# 4     0               1707       1645    -22       0
# 5     0               1707       1700     -7       0
# 6     0               1707       1655    -12       0
# 7     0               1712       1641    -31       0
# 8     0               1712       1652    -20       0
# 9     0               1712       1644    -28       0
# 10    0               1712       1658    -14       0
# 11    0               1712       1635    -37       0
# 12    0               1712       1637    -35       0
# 13    0               1712       1649    -23       0
# 14    0               1712       1656    -16       0
# 15    0               0133       0125     -8       0
# 16    0               0133       0105    -28       0
# 17    0               2159       2141    -18       0
# 18    0               2159       2137    -22       0
# 19    0               2159       2136    -23       0
# 20    0               2214       2215      1       1
# 21    0               2159       2149    -10       0
# 22    0               2159       2147    -12       0
# 23    0               2159       2200      1       1
# 24    0               2214       2207     -7       0
# 25    0               2159       2130    -29       0
# 26    0               2159       2135    -24       0
# 27    0               2159       2134    -25       0
# 28    0               2159       2207      8       8
# 29    0               2214       2232     18      18
# 30    0               2159       2149    -10       0
# ⋮     ⋮               ⋮          ⋮       ⋮        ⋮
# 18770 NA              1925       NA      NA       NA
# 18771 NA              1750       NA      NA       NA
# 18772 NA              1115       NA      NA       NA
# 18773 NA              2235       NA      NA       NA
# 18774 NA              1430       NA      NA       NA
# 18775 NA              1945       NA      NA       NA
# 18776 NA              1300       NA      NA       NA
# 18777 NA              2335       NA      NA       NA
# 18778 NA              1700       NA      NA       NA
# 18779 NA              1510       NA      NA       NA
# 18780 NA              1115       NA      NA       NA
# 18781 NA              1850       NA      NA       NA
# 18782 NA              2110       NA      NA       NA
# 18783 NA              1735       NA      NA       NA
# 18784 NA              1925       NA      NA       NA
# 18785 NA              1435       NA      NA       NA
# 18786 NA              1710       NA      NA       NA
# 18787 NA              0940       NA      NA       NA
# 18788 NA              1355       NA      NA       NA
# 18789 NA              1115       NA      NA       NA
# 18790 NA              1435       NA      NA       NA
# 18791 NA              1710       NA      NA       NA
# 18792 NA              1555       NA      NA       NA
# 18793 NA              1435       NA      NA       NA
# 18794 NA              1710       NA      NA       NA
# 18795 NA              1555       NA      NA       NA
# 18796 NA              1205       NA      NA       NA
# 18797 NA              1735       NA      NA       NA
# 18798 NA              1800       NA      NA       NA
# 18799 NA              1603       NA      NA       NA

# %%
my.df %>% 
  arrange(-DepDelayMinutes) -> my.df2

my.df2
# Out:
#       Year Month DayofMonth FlightDate Carrier TailNum FlightNum Origin
# 1     2017 6     18         2017-06-18 EV      N18556  4080      CMH
# 2     2017 6     29         2017-06-29 DL      N956DL  1897      ATL
# 3     2017 8      9         2017-08-09 F9      N223FR  1686      LAS
# 4     2017 1     29         2017-01-29 DL      N838DN  1897      ATL
# 5     2017 4      8         2017-04-08 DL      N984DL  1276      ATL
# 6     2017 1     23         2017-01-23 WN      N731SA  1886      DCA
# 7     2017 2     19         2017-02-19 UA      N812UA   515      CMH
# 8     2017 1     16         2017-01-16 EV      N607LR  5440      LGA
# 9     2017 2     24         2017-02-24 UA      N849UA   688      ORD
# 10    2017 8     17         2017-08-17 WN      N955WN  1031      STL
# 11    2017 4     30         2017-04-30 WN      N937WN  5531      MSY
# 12    2017 4      3         2017-04-03 DL      N930DL  1193      ATL
# 13    2017 1     24         2017-01-24 EV      N691CA  5333      MSP
# 14    2017 7     18         2017-07-18 WN      N7733B  3263      BOS
# 15    2017 1     11         2017-01-11 WN      N492WN   254      MDW
# 16    2017 3      7         2017-03-07 F9      N910FR  1694      MCO
# 17    2017 6     14         2017-06-14 WN      N224WN  1639      ATL
# 18    2017 4      3         2017-04-03 DL      N946DL  1152      ATL
# 19    2017 5     24         2017-05-24 WN      N7707C   158      TPA
# 20    2017 4      5         2017-04-05 WN      N635SW  2587      ATL
# 21    2017 5     11         2017-05-11 AA      N4YLAA  2452      DFW
# 22    2017 4      6         2017-04-06 WN      N429WN  1953      TPA
# 23    2017 5      7         2017-05-07 WN      N8670A  2747      OAK
# 24    2017 4      3         2017-04-03 DL      N329NW  1398      ATL
# 25    2017 7      9         2017-07-09 AA      N812AA   508      LAX
# 26    2017 7      2         2017-07-02 F9      N920FR  1694      MCO
# 27    2017 3      9         2017-03-09 WN      N376SW  1782      BOS
# 28    2017 9     11         2017-09-11 DL      N938DN  1152      ATL
# 29    2017 4      9         2017-04-09 WN      N621SW  6325      BNA
# 30    2017 6     15         2017-06-15 AA      N4XMAA   909      DFW
# ⋮     ⋮    ⋮     ⋮          ⋮          ⋮       ⋮       ⋮         ⋮
# 18770 2017 9     20         2017-09-20 WN      N7726A   494      BWI
# 18771 2017 9     10         2017-09-10 WN      NA      3675      MCO
# 18772 2017 9     10         2017-09-10 WN      NA      4643      MCO
# 18773 2017 9     10         2017-09-10 WN      N8327A  4930      MCO
# 18774 2017 9     10         2017-09-10 WN      N430WN  3714      RSW
# 18775 2017 9     10         2017-09-10 WN      N7818L  4454      TPA
# 18776 2017 9     10         2017-09-10 WN      N915WN  4701      TPA
# 18777 2017 9     11         2017-09-11 WN      N389SW    17      ATL
# 18778 2017 9     11         2017-09-11 WN      N639SW   188      ATL
# 18779 2017 9     11         2017-09-11 WN      N703SW  1816      DEN
# 18780 2017 9     11         2017-09-11 WN      N7878A  1792      MCO
# 18781 2017 9     11         2017-09-11 WN      N248WN  1888      MCO
# 18782 2017 9     11         2017-09-11 WN      N553WN   213      MDW
# 18783 2017 9     20         2017-09-20 WN      N947WN  5861      MDW
# 18784 2017 9      5         2017-09-05 WN      N726SW   494      BWI
# 18785 2017 9     11         2017-09-11 WN      NA       690      RSW
# 18786 2017 9     11         2017-09-11 WN      N484WN   924      TPA
# 18787 2017 9     12         2017-09-12 WN      NA       192      ATL
# 18788 2017 9     12         2017-09-12 WN      NA      1623      DCA
# 18789 2017 9     12         2017-09-12 WN      NA      1792      MCO
# 18790 2017 9     12         2017-09-12 WN      NA       690      RSW
# 18791 2017 9     12         2017-09-12 WN      N426WN   924      TPA
# 18792 2017 9     13         2017-09-13 WN      NA       938      MDW
# 18793 2017 9     13         2017-09-13 WN      NA       690      RSW
# 18794 2017 9     13         2017-09-13 WN      NA       924      TPA
# 18795 2017 9     14         2017-09-14 WN      N240WN   938      MDW
# 18796 2017 9     14         2017-09-14 WN      N430WN  1303      MDW
# 18797 2017 9     14         2017-09-14 WN      N403WN  5861      MDW
# 18798 2017 9     11         2017-09-11 DL      N935DN  1646      ATL
# 18799 2017 9     11         2017-09-11 DL      N921DL  1695      ATL
#       OriginCityName        Dest DestCityName CRSDepTime DepTime DepDelay
# 1     Columbus, OH          ORD  Chicago, IL  1340       0644    1024
# 2     Atlanta, GA           CMH  Columbus, OH 2109       0555     526
# 3     Las Vegas, NV         CMH  Columbus, OH 1615       0007     472
# 4     Atlanta, GA           CMH  Columbus, OH 2025       0330     425
# 5     Atlanta, GA           CMH  Columbus, OH 0925       1616     411
# 6     Washington, DC        CMH  Columbus, OH 1125       1807     402
# 7     Columbus, OH          ORD  Chicago, IL  1750       0024     394
# 8     New York, NY          CMH  Columbus, OH 1559       2216     377
# 9     Chicago, IL           CMH  Columbus, OH 1456       2112     376
# 10    St. Louis, MO         CMH  Columbus, OH 0820       1429     369
# 11    New Orleans, LA       CMH  Columbus, OH 1540       2143     363
# 12    Atlanta, GA           CMH  Columbus, OH 1747       2347     360
# 13    Minneapolis, MN       CMH  Columbus, OH 1015       1611     356
# 14    Boston, MA            CMH  Columbus, OH 0910       1505     355
# 15    Chicago, IL           CMH  Columbus, OH 1340       1934     354
# 16    Orlando, FL           CMH  Columbus, OH 0900       1442     342
# 17    Atlanta, GA           CMH  Columbus, OH 1520       2102     342
# 18    Atlanta, GA           CMH  Columbus, OH 1315       1856     341
# 19    Tampa, FL             CMH  Columbus, OH 1540       2119     339
# 20    Atlanta, GA           CMH  Columbus, OH 1600       2138     338
# 21    Dallas/Fort Worth, TX CMH  Columbus, OH 1830       0006     336
# 22    Tampa, FL             CMH  Columbus, OH 1600       2132     332
# 23    Oakland, CA           CMH  Columbus, OH 1140       1704     324
# 24    Atlanta, GA           CMH  Columbus, OH 1941       0058     317
# 25    Los Angeles, CA       CMH  Columbus, OH 0940       1457     317
# 26    Orlando, FL           CMH  Columbus, OH 0950       1506     316
# 27    Boston, MA            CMH  Columbus, OH 0805       1318     313
# 28    Atlanta, GA           CMH  Columbus, OH 1208       1720     312
# 29    Nashville, TN         CMH  Columbus, OH 1135       1646     311
# 30    Dallas/Fort Worth, TX CMH  Columbus, OH 1055       1606     311
# ⋮     ⋮                     ⋮    ⋮            ⋮          ⋮       ⋮
# 18770 Baltimore, MD         CMH  Columbus, OH 1810       NA      NA
# 18771 Orlando, FL           CMH  Columbus, OH 1545       NA      NA
# 18772 Orlando, FL           CMH  Columbus, OH 0910       NA      NA
# 18773 Orlando, FL           CMH  Columbus, OH 2025       NA      NA
# 18774 Fort Myers, FL        CMH  Columbus, OH 1210       NA      NA
# 18775 Tampa, FL             CMH  Columbus, OH 1740       NA      NA
# 18776 Tampa, FL             CMH  Columbus, OH 1055       NA      NA
# 18777 Atlanta, GA           CMH  Columbus, OH 2200       NA      NA
# 18778 Atlanta, GA           CMH  Columbus, OH 1525       NA      NA
# 18779 Denver, CO            CMH  Columbus, OH 1025       NA      NA
# 18780 Orlando, FL           CMH  Columbus, OH 0905       NA      NA
# 18781 Orlando, FL           CMH  Columbus, OH 1640       NA      NA
# 18782 Chicago, IL           CMH  Columbus, OH 1905       NA      NA
# 18783 Chicago, IL           CMH  Columbus, OH 1530       NA      NA
# 18784 Baltimore, MD         CMH  Columbus, OH 1810       NA      NA
# 18785 Fort Myers, FL        CMH  Columbus, OH 1215       NA      NA
# 18786 Tampa, FL             CMH  Columbus, OH 1500       NA      NA
# 18787 Atlanta, GA           CMH  Columbus, OH 0810       NA      NA
# 18788 Washington, DC        CMH  Columbus, OH 1240       NA      NA
# 18789 Orlando, FL           CMH  Columbus, OH 0905       NA      NA
# 18790 Fort Myers, FL        CMH  Columbus, OH 1215       NA      NA
# 18791 Tampa, FL             CMH  Columbus, OH 1500       NA      NA
# 18792 Chicago, IL           CMH  Columbus, OH 1345       NA      NA
# 18793 Fort Myers, FL        CMH  Columbus, OH 1215       NA      NA
# 18794 Tampa, FL             CMH  Columbus, OH 1500       NA      NA
# 18795 Chicago, IL           CMH  Columbus, OH 1345       NA      NA
# 18796 Chicago, IL           CMH  Columbus, OH 1000       NA      NA
# 18797 Chicago, IL           CMH  Columbus, OH 1530       NA      NA
# 18798 Atlanta, GA           CMH  Columbus, OH 1622       NA      NA
# 18799 Atlanta, GA           CMH  Columbus, OH 1430       NA      NA
#       DepDelayMinutes CRSArrTime ArrTime ArrDelay ArrDelayMinutes
# 1     1024            1405       0705    1020     1020
# 2      526            2249       0713     504      504
# 3      472            2314       0650     456      456
# 4      425            2157       0503     426      426
# 5      411            1058       1755     417      417
# 6      402            1250       1950     420      420
# 7      394            1821       0031     370      370
# 8      377            1804       2347     343      343
# 9      376            1715       2349     394      394
# 10     369            1045       1720     395      395
# 11     363            1850       0028     338      338
# 12     360            1919       0117     358      358
# 13     356            1328       1900     332      332
# 14     355            1120       1651     331      331
# 15     354            1550       2133     343      343
# 16     342            1112       1645     333      333
# 17     342            1655       2314     379      379
# 18     341            1445       2026     341      341
# 19     339            1755       2312     317      317
# 20     338            1730       0028     418      418
# 21     336            2151       0310     319      319
# 22     332            1815       2400     345      345
# 23     324            1910       0031     321      321
# 24     317            2116       0218     302      302
# 25     317            1715       2227     312      312
# 26     316            1204       1720     316      316
# 27     313            1020       1530     310      310
# 28     312            1345       1838     293      293
# 29     311            1340       1854     314      314
# 30     311            1421       1930     309      309
# ⋮     ⋮               ⋮          ⋮       ⋮        ⋮
# 18770 NA              1925       NA      NA       NA
# 18771 NA              1750       NA      NA       NA
# 18772 NA              1115       NA      NA       NA
# 18773 NA              2235       NA      NA       NA
# 18774 NA              1430       NA      NA       NA
# 18775 NA              1945       NA      NA       NA
# 18776 NA              1300       NA      NA       NA
# 18777 NA              2335       NA      NA       NA
# 18778 NA              1700       NA      NA       NA
# 18779 NA              1510       NA      NA       NA
# 18780 NA              1115       NA      NA       NA
# 18781 NA              1850       NA      NA       NA
# 18782 NA              2110       NA      NA       NA
# 18783 NA              1735       NA      NA       NA
# 18784 NA              1925       NA      NA       NA
# 18785 NA              1435       NA      NA       NA
# 18786 NA              1710       NA      NA       NA
# 18787 NA              0940       NA      NA       NA
# 18788 NA              1355       NA      NA       NA
# 18789 NA              1115       NA      NA       NA
# 18790 NA              1435       NA      NA       NA
# 18791 NA              1710       NA      NA       NA
# 18792 NA              1555       NA      NA       NA
# 18793 NA              1435       NA      NA       NA
# 18794 NA              1710       NA      NA       NA
# 18795 NA              1555       NA      NA       NA
# 18796 NA              1205       NA      NA       NA
# 18797 NA              1735       NA      NA       NA
# 18798 NA              1800       NA      NA       NA
# 18799 NA              1603       NA      NA       NA

# %%
my.df %>% 
  arrange(Dest, -DepDelayMinutes) -> my.df2

my.df2
# Out:
#       Year Month DayofMonth FlightDate Carrier TailNum FlightNum Origin
# 1     2017 6     29         2017-06-29 DL      N956DL  1897      ATL
# 2     2017 8      9         2017-08-09 F9      N223FR  1686      LAS
# 3     2017 1     29         2017-01-29 DL      N838DN  1897      ATL
# 4     2017 4      8         2017-04-08 DL      N984DL  1276      ATL
# 5     2017 1     23         2017-01-23 WN      N731SA  1886      DCA
# 6     2017 1     16         2017-01-16 EV      N607LR  5440      LGA
# 7     2017 2     24         2017-02-24 UA      N849UA   688      ORD
# 8     2017 8     17         2017-08-17 WN      N955WN  1031      STL
# 9     2017 4     30         2017-04-30 WN      N937WN  5531      MSY
# 10    2017 4      3         2017-04-03 DL      N930DL  1193      ATL
# 11    2017 1     24         2017-01-24 EV      N691CA  5333      MSP
# 12    2017 7     18         2017-07-18 WN      N7733B  3263      BOS
# 13    2017 1     11         2017-01-11 WN      N492WN   254      MDW
# 14    2017 3      7         2017-03-07 F9      N910FR  1694      MCO
# 15    2017 6     14         2017-06-14 WN      N224WN  1639      ATL
# 16    2017 4      3         2017-04-03 DL      N946DL  1152      ATL
# 17    2017 5     24         2017-05-24 WN      N7707C   158      TPA
# 18    2017 4      5         2017-04-05 WN      N635SW  2587      ATL
# 19    2017 5     11         2017-05-11 AA      N4YLAA  2452      DFW
# 20    2017 4      6         2017-04-06 WN      N429WN  1953      TPA
# 21    2017 5      7         2017-05-07 WN      N8670A  2747      OAK
# 22    2017 4      3         2017-04-03 DL      N329NW  1398      ATL
# 23    2017 7      9         2017-07-09 AA      N812AA   508      LAX
# 24    2017 7      2         2017-07-02 F9      N920FR  1694      MCO
# 25    2017 3      9         2017-03-09 WN      N376SW  1782      BOS
# 26    2017 9     11         2017-09-11 DL      N938DN  1152      ATL
# 27    2017 4      9         2017-04-09 WN      N621SW  6325      BNA
# 28    2017 6     15         2017-06-15 AA      N4XMAA   909      DFW
# 29    2017 6     19         2017-06-19 OO      N935SW  4520      DTW
# 30    2017 7     14         2017-07-14 WN      N467WN  1922      DAL
# ⋮     ⋮    ⋮     ⋮          ⋮          ⋮       ⋮       ⋮         ⋮
# 18770 2017 9     21         2017-09-21 UA      N78506  1014      CMH
# 18771 2017 9     20         2017-09-20 UA      N24729   515      CMH
# 18772 2017 9     20         2017-09-20 UA      N35260  1014      CMH
# 18773 2017 9     19         2017-09-19 UA      N16713   515      CMH
# 18774 2017 9     19         2017-09-19 UA      N76533  1014      CMH
# 18775 2017 9     18         2017-09-18 UA      N24729   515      CMH
# 18776 2017 9      3         2017-09-03 UA      N892UA   515      CMH
# 18777 2017 9      2         2017-09-02 UA      N463UA   515      CMH
# 18778 2017 9      2         2017-09-02 UA      N842UA   805      CMH
# 18779 2017 9      1         2017-09-01 UA      N38268   515      CMH
# 18780 2017 9     18         2017-09-18 UA      N73276  1014      CMH
# 18781 2017 9     15         2017-09-15 UA      N24729   515      CMH
# 18782 2017 9     15         2017-09-15 UA      N13248  1014      CMH
# 18783 2017 9     14         2017-09-14 UA      N17752   515      CMH
# 18784 2017 9      1         2017-09-01 UA      N17753  1802      CMH
# 18785 2017 9      9         2017-09-09 EV      N13550  3795      CMH
# 18786 2017 9     16         2017-09-16 EV      N13913  3795      CMH
# 18787 2017 9     23         2017-09-23 EV      N14993  3795      CMH
# 18788 2017 9     30         2017-09-30 EV      N26545  3795      CMH
# 18789 2017 5     18         2017-05-18 UA      NA       245      CMH
# 18790 2017 6     13         2017-06-13 OO      N141SY  5551      CMH
# 18791 2017 6     14         2017-06-14 OO      N128SY  5551      CMH
# 18792 2017 7     20         2017-07-20 OO      N120SY  5386      CMH
# 18793 2017 7     21         2017-07-21 OO      N148SY  5386      CMH
# 18794 2017 7     23         2017-07-23 OO      N209SY  5386      CMH
# 18795 2017 7     10         2017-07-10 OO      N140SY  5386      CMH
# 18796 2017 7     12         2017-07-12 OO      N125SY  5386      CMH
# 18797 2017 8      1         2017-08-01 OO      N120SY  5386      CMH
# 18798 2017 8      3         2017-08-03 OO      N203SY  5386      CMH
# 18799 2017 8      4         2017-08-04 OO      N145SY  5386      CMH
#       OriginCityName        Dest DestCityName CRSDepTime DepTime DepDelay
# 1     Atlanta, GA           CMH  Columbus, OH 2109       0555    526
# 2     Las Vegas, NV         CMH  Columbus, OH 1615       0007    472
# 3     Atlanta, GA           CMH  Columbus, OH 2025       0330    425
# 4     Atlanta, GA           CMH  Columbus, OH 0925       1616    411
# 5     Washington, DC        CMH  Columbus, OH 1125       1807    402
# 6     New York, NY          CMH  Columbus, OH 1559       2216    377
# 7     Chicago, IL           CMH  Columbus, OH 1456       2112    376
# 8     St. Louis, MO         CMH  Columbus, OH 0820       1429    369
# 9     New Orleans, LA       CMH  Columbus, OH 1540       2143    363
# 10    Atlanta, GA           CMH  Columbus, OH 1747       2347    360
# 11    Minneapolis, MN       CMH  Columbus, OH 1015       1611    356
# 12    Boston, MA            CMH  Columbus, OH 0910       1505    355
# 13    Chicago, IL           CMH  Columbus, OH 1340       1934    354
# 14    Orlando, FL           CMH  Columbus, OH 0900       1442    342
# 15    Atlanta, GA           CMH  Columbus, OH 1520       2102    342
# 16    Atlanta, GA           CMH  Columbus, OH 1315       1856    341
# 17    Tampa, FL             CMH  Columbus, OH 1540       2119    339
# 18    Atlanta, GA           CMH  Columbus, OH 1600       2138    338
# 19    Dallas/Fort Worth, TX CMH  Columbus, OH 1830       0006    336
# 20    Tampa, FL             CMH  Columbus, OH 1600       2132    332
# 21    Oakland, CA           CMH  Columbus, OH 1140       1704    324
# 22    Atlanta, GA           CMH  Columbus, OH 1941       0058    317
# 23    Los Angeles, CA       CMH  Columbus, OH 0940       1457    317
# 24    Orlando, FL           CMH  Columbus, OH 0950       1506    316
# 25    Boston, MA            CMH  Columbus, OH 0805       1318    313
# 26    Atlanta, GA           CMH  Columbus, OH 1208       1720    312
# 27    Nashville, TN         CMH  Columbus, OH 1135       1646    311
# 28    Dallas/Fort Worth, TX CMH  Columbus, OH 1055       1606    311
# 29    Detroit, MI           CMH  Columbus, OH 0835       1331    296
# 30    Dallas, TX            CMH  Columbus, OH 1930       0024    294
# ⋮     ⋮                     ⋮    ⋮            ⋮          ⋮       ⋮
# 18770 Columbus, OH          ORD  Chicago, IL  1050       1045     -5
# 18771 Columbus, OH          ORD  Chicago, IL  1721       1717     -4
# 18772 Columbus, OH          ORD  Chicago, IL  1050       1043     -7
# 18773 Columbus, OH          ORD  Chicago, IL  1721       1711    -10
# 18774 Columbus, OH          ORD  Chicago, IL  1050       1045     -5
# 18775 Columbus, OH          ORD  Chicago, IL  1721       1718     -3
# 18776 Columbus, OH          ORD  Chicago, IL  1611       1607     -4
# 18777 Columbus, OH          ORD  Chicago, IL  1757       1745    -12
# 18778 Columbus, OH          ORD  Chicago, IL  1045       1040     -5
# 18779 Columbus, OH          ORD  Chicago, IL  1801       1759     -2
# 18780 Columbus, OH          ORD  Chicago, IL  1050       1045     -5
# 18781 Columbus, OH          ORD  Chicago, IL  1721       1717     -4
# 18782 Columbus, OH          ORD  Chicago, IL  1050       1045     -5
# 18783 Columbus, OH          ORD  Chicago, IL  1721       1705    -16
# 18784 Columbus, OH          ORD  Chicago, IL  1928       1923     -5
# 18785 Columbus, OH          ORD  Chicago, IL  1345       1336     -9
# 18786 Columbus, OH          ORD  Chicago, IL  1345       1335    -10
# 18787 Columbus, OH          ORD  Chicago, IL  1345       1340     -5
# 18788 Columbus, OH          ORD  Chicago, IL  1345       1335    -10
# 18789 Columbus, OH          ORD  Chicago, IL  0730       NA       NA
# 18790 Columbus, OH          ORD  Chicago, IL  2043       NA       NA
# 18791 Columbus, OH          ORD  Chicago, IL  2043       NA       NA
# 18792 Columbus, OH          ORD  Chicago, IL  2045       NA       NA
# 18793 Columbus, OH          ORD  Chicago, IL  2045       NA       NA
# 18794 Columbus, OH          ORD  Chicago, IL  2045       NA       NA
# 18795 Columbus, OH          ORD  Chicago, IL  2045       NA       NA
# 18796 Columbus, OH          ORD  Chicago, IL  2045       NA       NA
# 18797 Columbus, OH          ORD  Chicago, IL  2045       NA       NA
# 18798 Columbus, OH          ORD  Chicago, IL  2045       NA       NA
# 18799 Columbus, OH          ORD  Chicago, IL  2040       NA       NA
#       DepDelayMinutes CRSArrTime ArrTime ArrDelay ArrDelayMinutes
# 1     526             2249       0713    504      504
# 2     472             2314       0650    456      456
# 3     425             2157       0503    426      426
# 4     411             1058       1755    417      417
# 5     402             1250       1950    420      420
# 6     377             1804       2347    343      343
# 7     376             1715       2349    394      394
# 8     369             1045       1720    395      395
# 9     363             1850       0028    338      338
# 10    360             1919       0117    358      358
# 11    356             1328       1900    332      332
# 12    355             1120       1651    331      331
# 13    354             1550       2133    343      343
# 14    342             1112       1645    333      333
# 15    342             1655       2314    379      379
# 16    341             1445       2026    341      341
# 17    339             1755       2312    317      317
# 18    338             1730       0028    418      418
# 19    336             2151       0310    319      319
# 20    332             1815       2400    345      345
# 21    324             1910       0031    321      321
# 22    317             2116       0218    302      302
# 23    317             1715       2227    312      312
# 24    316             1204       1720    316      316
# 25    313             1020       1530    310      310
# 26    312             1345       1838    293      293
# 27    311             1340       1854    314      314
# 28    311             1421       1930    309      309
# 29    296             0939       1424    285      285
# 30    294             2250       0335    285      285
# ⋮     ⋮               ⋮          ⋮       ⋮        ⋮
# 18770  0              1115       1050    -25       0
# 18771  0              1750       1721    -29       0
# 18772  0              1115       1058    -17       0
# 18773  0              1750       1803     13      13
# 18774  0              1115       1107     -8       0
# 18775  0              1750       1748     -2       0
# 18776  0              1644       1609    -35       0
# 18777  0              1828       1747    -41       0
# 18778  0              1109       1039    -30       0
# 18779  0              1833       1842      9       9
# 18780  0              1115       1110     -5       0
# 18781  0              1750       1714    -36       0
# 18782  0              1115       1104    -11       0
# 18783  0              1750       1708    -42       0
# 18784  0              1959       2019     20      20
# 18785  0              1413       1409     -4       0
# 18786  0              1413       1353    -20       0
# 18787  0              1413       1402    -11       0
# 18788  0              1413       1400    -13       0
# 18789 NA              0757       NA       NA      NA
# 18790 NA              2113       NA       NA      NA
# 18791 NA              2113       NA       NA      NA
# 18792 NA              2113       NA       NA      NA
# 18793 NA              2113       NA       NA      NA
# 18794 NA              2113       NA       NA      NA
# 18795 NA              2113       NA       NA      NA
# 18796 NA              2113       NA       NA      NA
# 18797 NA              2113       NA       NA      NA
# 18798 NA              2113       NA       NA      NA
# 18799 NA              2108       NA       NA      NA

# %%
cmhflights %>% 
  select(Month, UniqueCarrier, Dest, DepDelayMinutes) %>% 
  filter(
    Month %in% c(1, 2), UniqueCarrier == "UA", Dest %in% c("CMH", "ORD")
    ) %>% 
  arrange(Month, Dest, -DepDelayMinutes) -> my.df3

my.df3
# Out:
#     Month UniqueCarrier Dest DepDelayMinutes
# 1   1     UA            CMH  178
# 2   1     UA            CMH   61
# 3   1     UA            CMH   44
# 4   1     UA            CMH   39
# 5   1     UA            CMH   39
# 6   1     UA            CMH   30
# 7   1     UA            CMH   27
# 8   1     UA            CMH   18
# 9   1     UA            CMH   12
# 10  1     UA            CMH   10
# 11  1     UA            CMH    8
# 12  1     UA            CMH    2
# 13  1     UA            CMH    2
# 14  1     UA            CMH    2
# 15  1     UA            CMH    1
# 16  1     UA            CMH    1
# 17  1     UA            CMH    1
# 18  1     UA            CMH    0
# 19  1     UA            CMH    0
# 20  1     UA            CMH    0
# 21  1     UA            CMH    0
# 22  1     UA            CMH    0
# 23  1     UA            CMH    0
# 24  1     UA            CMH    0
# 25  1     UA            CMH    0
# 26  1     UA            CMH    0
# 27  1     UA            CMH    0
# 28  1     UA            CMH    0
# 29  1     UA            CMH    0
# 30  1     UA            CMH    0
# ⋮   ⋮     ⋮             ⋮    ⋮
# 222 2     UA            ORD  0
# 223 2     UA            ORD  0
# 224 2     UA            ORD  0
# 225 2     UA            ORD  0
# 226 2     UA            ORD  0
# 227 2     UA            ORD  0
# 228 2     UA            ORD  0
# 229 2     UA            ORD  0
# 230 2     UA            ORD  0
# 231 2     UA            ORD  0
# 232 2     UA            ORD  0
# 233 2     UA            ORD  0
# 234 2     UA            ORD  0
# 235 2     UA            ORD  0
# 236 2     UA            ORD  0
# 237 2     UA            ORD  0
# 238 2     UA            ORD  0
# 239 2     UA            ORD  0
# 240 2     UA            ORD  0
# 241 2     UA            ORD  0
# 242 2     UA            ORD  0
# 243 2     UA            ORD  0
# 244 2     UA            ORD  0
# 245 2     UA            ORD  0
# 246 2     UA            ORD  0
# 247 2     UA            ORD  0
# 248 2     UA            ORD  0
# 249 2     UA            ORD  0
# 250 2     UA            ORD  0
# 251 2     UA            ORD  0

# %%
cmhflights %>%
  count(Month) # Most flights were in July (n = 4295)
# Out:
#   Month n
# 1 1     3757
# 2 2     3413
# 3 3     4101
# 4 4     4123
# 5 5     4098
# 6 6     4138
# 7 7     4295
# 8 8     4279
# 9 9     3789

# %%
cmhflights %>%
  count(Month, DayOfWeek) # Output is sorted by Month and then DayOfWeek
# Out:
#    Month DayOfWeek n
# 1  1     1         660
# 2  1     2         635
# 3  1     3         516
# 4  1     4         522
# 5  1     5         523
# 6  1     6         361
# 7  1     7         540
# 8  2     1         527
# 9  2     2         506
# 10 2     3         516
# 11 2     4         531
# 12 2     5         528
# 13 2     6         371
# 14 2     7         434
# 15 3     1         549
# 16 3     2         546
# 17 3     3         674
# 18 3     4         695
# 19 3     5         685
# 20 3     6         447
# 21 3     7         505
# 22 4     1         584
# 23 4     2         569
# 24 4     3         570
# 25 4     4         580
# 26 4     5         576
# 27 4     6         581
# 28 4     7         663
# 29 5     1         683
# 30 5     2         685
# ⋮  ⋮     ⋮         ⋮
# 34 5     6         418
# 35 5     7         507
# 36 6     1         561
# 37 6     2         567
# 38 6     3         572
# 39 6     4         701
# 40 6     5         701
# 41 6     6         482
# 42 6     7         554
# 43 7     1         703
# 44 7     2         549
# 45 7     3         584
# 46 7     4         578
# 47 7     5         574
# 48 7     6         633
# 49 7     7         674
# 50 8     1         580
# 51 8     2         696
# 52 8     3         712
# 53 8     4         718
# 54 8     5         581
# 55 8     6         458
# 56 8     7         534
# 57 9     1         548
# 58 9     2         531
# 59 9     3         539
# 60 9     4         550
# 61 9     5         689
# 62 9     6         451
# 63 9     7         481

# %%
cmhflights %>%
  summarise(
      mean_arr_delay = mean(ArrDelay, na.rm = TRUE),
      mean_dep_delay = mean(DepDelay, na.rm = TRUE),
      median_arr_delay = median(ArrDelay, na.rm = TRUE),
      median_dep_delay = median(DepDelay, na.rm = TRUE),
      variance_arr_delay = median(ArrDelay, na.rm = TRUE),
      variance_dep_delay = median(DepDelay, na.rm = TRUE),  
      sd_arr_delay = sd(ArrDelay, na.rm = TRUE),
      sd_dep_delay = sd(DepDelay, na.rm = TRUE)
  )
# Out:
#   mean_arr_delay mean_dep_delay median_arr_delay median_dep_delay
# 1 3.258327       9.202072       -6               -2
#   variance_arr_delay variance_dep_delay sd_arr_delay sd_dep_delay
# 1 -6                 -2                 41.78856     39.77119

# %%
df = data.frame(x = c(2, 4, 9, NA))

# %%
df %>%
  summarise(mean.x = mean(x)) # You get no meaningful values
# Out:
#   mean.x
# 1 NA

# %%
df %>%
  summarise(mean.x = mean(x, na.rm = TRUE)) # Now you do get something meaningful
# Out:
#   mean.x
# 1 5

# %%
cmhflights %>%
    group_by(Carrier) %>%
    summarize(sum(DepDelay, na.rm = TRUE))
# Out:
#   Carrier sum(DepDelay, na.rm = TRUE)
# 1 AA       29853
# 2 DL       38297
# 3 EV       44146
# 4 F9       16834
# 5 OO       13006
# 6 UA        9739
# 7 WN      175001

# %%
cmhflights %>%
  group_by(Month, Carrier) %>%
  tally()
# Out:
#    Month Carrier n
# 1  1     AA       387
# 2  1     DL       549
# 3  1     EV       436
# 4  1     F9       152
# 5  1     OO       123
# 6  1     UA       106
# 7  1     WN      2004
# 8  2     AA       360
# 9  2     DL       511
# 10 2     EV       362
# 11 2     F9       136
# 12 2     OO       100
# 13 2     UA       156
# 14 2     WN      1788
# 15 3     AA       418
# 16 3     DL       543
# 17 3     EV       408
# 18 3     F9       170
# 19 3     OO       116
# 20 3     UA       193
# 21 3     WN      2253
# 22 4     AA       442
# 23 4     DL       554
# 24 4     EV       316
# 25 4     F9       192
# 26 4     OO       288
# 27 4     UA       142
# 28 4     WN      2189
# 29 5     AA       442
# 30 5     DL       694
# ⋮  ⋮     ⋮       ⋮
# 34 5     UA       178
# 35 5     WN      2052
# 36 6     AA       485
# 37 6     DL       646
# 38 6     EV       359
# 39 6     F9       180
# 40 6     OO       180
# 41 6     UA       184
# 42 6     WN      2104
# 43 7     AA       500
# 44 7     DL       674
# 45 7     EV       251
# 46 7     F9       186
# 47 7     OO       316
# 48 7     UA       194
# 49 7     WN      2174
# 50 8     AA       488
# 51 8     DL       666
# 52 8     EV       348
# 53 8     F9       186
# 54 8     OO       336
# 55 8     UA       178
# 56 8     WN      2077
# 57 9     AA       369
# 58 9     DL       609
# 59 9     EV       294
# 60 9     F9       180
# 61 9     OO       318
# 62 9     UA       196
# 63 9     WN      1823

# %%
cmhflights %>%
  group_by(Month, Carrier) %>%
  summarize(
    frequency = n()
    )
# Out:
# `summarise()` has grouped output by 'Month'. You can override using the `.groups` argument.
#    Month Carrier frequency
# 1  1     AA       387
# 2  1     DL       549
# 3  1     EV       436
# 4  1     F9       152
# 5  1     OO       123
# 6  1     UA       106
# 7  1     WN      2004
# 8  2     AA       360
# 9  2     DL       511
# 10 2     EV       362
# 11 2     F9       136
# 12 2     OO       100
# 13 2     UA       156
# 14 2     WN      1788
# 15 3     AA       418
# 16 3     DL       543
# 17 3     EV       408
# 18 3     F9       170
# 19 3     OO       116
# 20 3     UA       193
# 21 3     WN      2253
# 22 4     AA       442
# 23 4     DL       554
# 24 4     EV       316
# 25 4     F9       192
# 26 4     OO       288
# 27 4     UA       142
# 28 4     WN      2189
# 29 5     AA       442
# 30 5     DL       694
# ⋮  ⋮     ⋮       ⋮
# 34 5     UA       178
# 35 5     WN      2052
# 36 6     AA       485
# 37 6     DL       646
# 38 6     EV       359
# 39 6     F9       180
# 40 6     OO       180
# 41 6     UA       184
# 42 6     WN      2104
# 43 7     AA       500
# 44 7     DL       674
# 45 7     EV       251
# 46 7     F9       186
# 47 7     OO       316
# 48 7     UA       194
# 49 7     WN      2174
# 50 8     AA       488
# 51 8     DL       666
# 52 8     EV       348
# 53 8     F9       186
# 54 8     OO       336
# 55 8     UA       178
# 56 8     WN      2077
# 57 9     AA       369
# 58 9     DL       609
# 59 9     EV       294
# 60 9     F9       180
# 61 9     OO       318
# 62 9     UA       196
# 63 9     WN      1823

# %%
cmhflights %>%
  group_by(Month, Carrier, Dest) %>%
  tally()
# Out:
#     Month Carrier Dest n
# 1   1     AA      CMH  193
# 2   1     AA      DFW  112
# 3   1     AA      LAX   24
# 4   1     AA      PHX   58
# 5   1     DL      ATL  224
# 6   1     DL      CMH  275
# 7   1     DL      DTW    2
# 8   1     DL      LAX   27
# 9   1     DL      MSP   21
# 10  1     EV      CMH  218
# 11  1     EV      EWR   82
# 12  1     EV      IAH   72
# 13  1     EV      LGA   42
# 14  1     EV      MSP   18
# 15  1     EV      ORD    4
# 16  1     F9      CMH   76
# 17  1     F9      DEN   31
# 18  1     F9      LAS   31
# 19  1     F9      MCO   14
# 20  1     OO      CMH   61
# 21  1     OO      DTW   56
# 22  1     OO      IAH    1
# 23  1     OO      MSP    2
# 24  1     OO      ORD    3
# 25  1     UA      CMH   53
# 26  1     UA      ORD   53
# 27  1     WN      ATL   84
# 28  1     WN      BNA   54
# 29  1     WN      BOS   49
# 30  1     WN      BWI   90
# ⋮   ⋮     ⋮       ⋮    ⋮
# 369 9     F9      DEN   30
# 370 9     F9      LAS   30
# 371 9     F9      MCO   30
# 372 9     OO      CMH  159
# 373 9     OO      DEN    3
# 374 9     OO      DTW   65
# 375 9     OO      MSP   21
# 376 9     OO      ORD   70
# 377 9     UA      CMH   98
# 378 9     UA      DEN   49
# 379 9     UA      IAH    1
# 380 9     UA      ORD   48
# 381 9     WN      ATL   80
# 382 9     WN      BNA   55
# 383 9     WN      BOS   54
# 384 9     WN      BWI  109
# 385 9     WN      CMH  912
# 386 9     WN      DAL   30
# 387 9     WN      DCA   55
# 388 9     WN      DEN   32
# 389 9     WN      FLL    5
# 390 9     WN      LAS   58
# 391 9     WN      MCO   65
# 392 9     WN      MDW  187
# 393 9     WN      MSY    4
# 394 9     WN      OAK   30
# 395 9     WN      PHX   30
# 396 9     WN      RSW   30
# 397 9     WN      STL   54
# 398 9     WN      TPA   33

# %%
cmhflights %>%
  group_by(Month, Carrier, Dest, DayOfWeek) %>%
  tally()
# Out:
#      Month Carrier Dest DayOfWeek n
# 1    1     AA      CMH  1         35
# 2    1     AA      CMH  2         23
# 3    1     AA      CMH  3         28
# 4    1     AA      CMH  4         28
# 5    1     AA      CMH  5         28
# 6    1     AA      CMH  6         21
# 7    1     AA      CMH  7         30
# 8    1     AA      DFW  1         20
# 9    1     AA      DFW  2         16
# 10   1     AA      DFW  3         16
# 11   1     AA      DFW  4         16
# 12   1     AA      DFW  5         16
# 13   1     AA      DFW  6          9
# 14   1     AA      DFW  7         19
# 15   1     AA      LAX  1          5
# 16   1     AA      LAX  2          1
# 17   1     AA      LAX  3          4
# 18   1     AA      LAX  4          4
# 19   1     AA      LAX  5          4
# 20   1     AA      LAX  6          1
# 21   1     AA      LAX  7          5
# 22   1     AA      PHX  1         10
# 23   1     AA      PHX  2          6
# 24   1     AA      PHX  3          8
# 25   1     AA      PHX  4          8
# 26   1     AA      PHX  5          8
# 27   1     AA      PHX  6          8
# 28   1     AA      PHX  7         10
# 29   1     DL      ATL  1         40
# 30   1     DL      ATL  2         40
# ⋮    ⋮     ⋮       ⋮    ⋮         ⋮
# 2507 9     WN      OAK  6          5
# 2508 9     WN      OAK  7          4
# 2509 9     WN      PHX  1          4
# 2510 9     WN      PHX  2          4
# 2511 9     WN      PHX  3          4
# 2512 9     WN      PHX  4          4
# 2513 9     WN      PHX  5          5
# 2514 9     WN      PHX  6          5
# 2515 9     WN      PHX  7          4
# 2516 9     WN      RSW  1          4
# 2517 9     WN      RSW  2          4
# 2518 9     WN      RSW  3          4
# 2519 9     WN      RSW  4          4
# 2520 9     WN      RSW  5          5
# 2521 9     WN      RSW  6          5
# 2522 9     WN      RSW  7          4
# 2523 9     WN      STL  1          8
# 2524 9     WN      STL  2          8
# 2525 9     WN      STL  3          8
# 2526 9     WN      STL  4          8
# 2527 9     WN      STL  5         10
# 2528 9     WN      STL  6          5
# 2529 9     WN      STL  7          7
# 2530 9     WN      TPA  1          4
# 2531 9     WN      TPA  2          4
# 2532 9     WN      TPA  3          4
# 2533 9     WN      TPA  4          4
# 2534 9     WN      TPA  5          5
# 2535 9     WN      TPA  6          5
# 2536 9     WN      TPA  7          7

# %%
cmhflights %>%
  group_by(Month, Carrier, Dest, DayOfWeek) %>%
  summarise(mean_dep_delay = mean(DepDelay, na.rm = TRUE))
# Out:
# `summarise()` has grouped output by 'Month', 'Carrier', 'Dest'. You can override using the `.groups` argument.
#      Month Carrier Dest DayOfWeek mean_dep_delay
# 1    1     AA      CMH  1         16.2857143
# 2    1     AA      CMH  2          0.3043478
# 3    1     AA      CMH  3          1.1428571
# 4    1     AA      CMH  4          3.1071429
# 5    1     AA      CMH  5          4.1071429
# 6    1     AA      CMH  6         24.8571429
# 7    1     AA      CMH  7         21.8333333
# 8    1     AA      DFW  1         25.4000000
# 9    1     AA      DFW  2         -2.6250000
# 10   1     AA      DFW  3         17.6000000
# 11   1     AA      DFW  4         -0.1875000
# 12   1     AA      DFW  5          3.8750000
# 13   1     AA      DFW  6         35.6666667
# 14   1     AA      DFW  7         50.2105263
# 15   1     AA      LAX  1          3.4000000
# 16   1     AA      LAX  2         -4.0000000
# 17   1     AA      LAX  3         -0.5000000
# 18   1     AA      LAX  4          2.5000000
# 19   1     AA      LAX  5         -1.5000000
# 20   1     AA      LAX  6         -3.0000000
# 21   1     AA      LAX  7         -5.8000000
# 22   1     AA      PHX  1          1.7000000
# 23   1     AA      PHX  2         -4.6666667
# 24   1     AA      PHX  3         -0.1250000
# 25   1     AA      PHX  4         -0.7500000
# 26   1     AA      PHX  5         -0.8750000
# 27   1     AA      PHX  6         -5.6250000
# 28   1     AA      PHX  7         27.9000000
# 29   1     DL      ATL  1         29.9459459
# 30   1     DL      ATL  2          1.1500000
# ⋮    ⋮     ⋮       ⋮    ⋮         ⋮
# 2507 9     WN      OAK  6          4.4000000
# 2508 9     WN      OAK  7          1.7500000
# 2509 9     WN      PHX  1         22.0000000
# 2510 9     WN      PHX  2         13.5000000
# 2511 9     WN      PHX  3         29.5000000
# 2512 9     WN      PHX  4         16.7500000
# 2513 9     WN      PHX  5          8.0000000
# 2514 9     WN      PHX  6         -1.4000000
# 2515 9     WN      PHX  7         15.7500000
# 2516 9     WN      RSW  1         -0.3333333
# 2517 9     WN      RSW  2          2.3333333
# 2518 9     WN      RSW  3         -5.3333333
# 2519 9     WN      RSW  4         16.7500000
# 2520 9     WN      RSW  5         22.6000000
# 2521 9     WN      RSW  6         -1.2500000
# 2522 9     WN      RSW  7         -1.6666667
# 2523 9     WN      STL  1         20.2500000
# 2524 9     WN      STL  2         -3.0000000
# 2525 9     WN      STL  3         -3.8750000
# 2526 9     WN      STL  4         14.3750000
# 2527 9     WN      STL  5         -1.2000000
# 2528 9     WN      STL  6         -3.2000000
# 2529 9     WN      STL  7         -5.5714286
# 2530 9     WN      TPA  1          5.3333333
# 2531 9     WN      TPA  2          7.0000000
# 2532 9     WN      TPA  3          2.0000000
# 2533 9     WN      TPA  4         13.0000000
# 2534 9     WN      TPA  5         14.8000000
# 2535 9     WN      TPA  6          0.0000000
# 2536 9     WN      TPA  7          6.8000000

# %%
cmhflights %>%
  group_by(Carrier) %>%
  summarise(mean_dep_delay = mean(DepDelay, na.rm = TRUE)) %>%
  arrange(-mean_dep_delay) # ordered in descending order of delays
# Out:
#   Carrier mean_dep_delay
# 1 EV      15.207027
# 2 F9      10.839665
# 3 WN       9.581221
# 4 AA       7.733938
# 5 DL       7.095979
# 6 OO       6.438614
# 7 UA       6.390420

# %%
cmhflights %>%
  group_by(Carrier, Month) %>%
  summarise(mean_dep_delay = mean(DepDelay, na.rm = TRUE)) %>%
  arrange(mean_dep_delay) # ordered in descending order of delays
# Out:
# `summarise()` has grouped output by 'Carrier'. You can override using the `.groups` argument.
#    Carrier Month mean_dep_delay
# 1  OO      8     -0.8727273
# 2  OO      2     -0.5700000
# 3  OO      9     -0.1792453
# 4  UA      9      0.6989796
# 5  DL      8      1.8528529
# 6  DL      2      2.2367906
# 7  AA      2      2.3027778
# 8  F9      9      2.5086705
# 9  AA      9      2.6250000
# 10 DL      3      2.9815838
# 11 UA      4      3.1690141
# 12 UA      8      3.5337079
# 13 WN      2      3.6589758
# 14 F9      2      3.8308824
# 15 DL      9      3.9107438
# 16 DL      5      3.9927954
# 17 UA      5      4.2881356
# 18 UA      1      4.5754717
# 19 UA      3      4.8704663
# 20 F9      4      5.6789474
# 21 WN      3      6.0947226
# 22 UA      2      6.2243590
# 23 OO      4      6.4895833
# 24 AA      5      6.5609195
# 25 WN      9      6.6165627
# 26 AA      8      6.8822314
# 27 F9      5      7.4130435
# 28 AA      4      7.7597254
# 29 AA      3      7.8851675
# 30 WN      1      8.1796165
# ⋮  ⋮       ⋮     ⋮
# 34 WN      5     10.30390
# 35 OO      5     10.43561
# 36 EV      8     10.80317
# 37 OO      6     10.93750
# 38 AA      1     10.99482
# 39 AA      6     11.17537
# 40 OO      3     11.21053
# 41 DL      7     11.28338
# 42 AA      7     11.33671
# 43 F9      6     11.98333
# 44 WN      8     12.13687
# 45 EV      2     12.31858
# 46 OO      7     12.73290
# 47 DL      1     13.04833
# 48 OO      1     13.59350
# 49 EV      5     14.05495
# 50 UA      6     14.09239
# 51 F9      8     14.10870
# 52 WN      6     14.18984
# 53 WN      7     14.19621
# 54 UA      7     14.45312
# 55 F9      3     14.67059
# 56 F9      7     14.96774
# 57 EV      6     15.17094
# 58 EV      3     16.45845
# 59 EV      1     16.86744
# 60 DL      4     17.72500
# 61 EV      4     17.77199
# 62 F9      1     22.70000
# 63 EV      7     25.47034

# %%
cmhflights %>%
  select(c(Carrier, DepDelay)) %>%
  filter(
      Carrier %in% c("AA", "DL", "UA", "WN")
  ) %>%
  mutate(
      late = case_when(
          DepDelay > 0 ~ "Yes",
          DepDelay <= 0 ~ "No"
      )
  ) %>% 
  group_by(Carrier) %>%
  mutate(
      nflights = n()
  ) %>%
  group_by(Carrier, late) %>%
  mutate(
    nlate = n(),
    pct_late = (nlate / nflights) * 100
  ) -> df1

df1
# Out:
#       Carrier DepDelay late nflights nlate pct_late
# 1     AA       -9      No   3891     2698  69.33950
# 2     AA       24      Yes  3891     1162  29.86379
# 3     AA       -6      No   3891     2698  69.33950
# 4     AA       -5      No   3891     2698  69.33950
# 5     AA       -7      No   3891     2698  69.33950
# 6     AA       22      Yes  3891     1162  29.86379
# 7     AA       -4      No   3891     2698  69.33950
# 8     AA       -4      No   3891     2698  69.33950
# 9     AA       42      Yes  3891     1162  29.86379
# 10    AA       -6      No   3891     2698  69.33950
# 11    AA       -5      No   3891     2698  69.33950
# 12    AA       -3      No   3891     2698  69.33950
# 13    AA      106      Yes  3891     1162  29.86379
# 14    AA        4      Yes  3891     1162  29.86379
# 15    AA        0      No   3891     2698  69.33950
# 16    AA        6      Yes  3891     1162  29.86379
# 17    AA        7      Yes  3891     1162  29.86379
# 18    AA       22      Yes  3891     1162  29.86379
# 19    AA       31      Yes  3891     1162  29.86379
# 20    AA       -8      No   3891     2698  69.33950
# 21    AA       -5      No   3891     2698  69.33950
# 22    AA       -3      No   3891     2698  69.33950
# 23    AA       32      Yes  3891     1162  29.86379
# 24    AA       -3      No   3891     2698  69.33950
# 25    AA       -3      No   3891     2698  69.33950
# 26    AA       61      Yes  3891     1162  29.86379
# 27    AA       -4      No   3891     2698  69.33950
# 28    AA        8      Yes  3891     1162  29.86379
# 29    AA        0      No   3891     2698  69.33950
# 30    AA       -3      No   3891     2698  69.33950
# ⋮     ⋮       ⋮        ⋮    ⋮        ⋮     ⋮
# 29299 DL      -2       No   5446     3887  71.37349
# 29300 DL      87       Yes  5446     1510  27.72677
# 29301 DL      -6       No   5446     3887  71.37349
# 29302 DL      36       Yes  5446     1510  27.72677
# 29303 DL      -3       No   5446     3887  71.37349
# 29304 DL      -5       No   5446     3887  71.37349
# 29305 DL       6       Yes  5446     1510  27.72677
# 29306 DL      -7       No   5446     3887  71.37349
# 29307 DL      -6       No   5446     3887  71.37349
# 29308 DL      -8       No   5446     3887  71.37349
# 29309 DL      -2       No   5446     3887  71.37349
# 29310 DL      -3       No   5446     3887  71.37349
# 29311 DL      -3       No   5446     3887  71.37349
# 29312 DL      -6       No   5446     3887  71.37349
# 29313 DL      -4       No   5446     3887  71.37349
# 29314 DL      -3       No   5446     3887  71.37349
# 29315 DL      -3       No   5446     3887  71.37349
# 29316 DL      -3       No   5446     3887  71.37349
# 29317 DL      -4       No   5446     3887  71.37349
# 29318 DL       9       Yes  5446     1510  27.72677
# 29319 DL      -1       No   5446     3887  71.37349
# 29320 DL      -5       No   5446     3887  71.37349
# 29321 DL      -3       No   5446     3887  71.37349
# 29322 DL      -2       No   5446     3887  71.37349
# 29323 DL      -3       No   5446     3887  71.37349
# 29324 DL      -2       No   5446     3887  71.37349
# 29325 DL      -6       No   5446     3887  71.37349
# 29326 DL       1       Yes  5446     1510  27.72677
# 29327 DL      -5       No   5446     3887  71.37349
# 29328 DL      -4       No   5446     3887  71.37349

# %%
df1 %>%
  filter(late == "Yes") %>%
  ungroup() %>%
  select(Carrier, pct_late) %>%
  distinct() %>%
  arrange(pct_late)
# Out:
#   Carrier pct_late
# 1 UA      23.96857
# 2 DL      27.72677
# 3 AA      29.86379
# 4 WN      41.06911

# %%
cmhflights %>%
  select(c(Carrier, Month, DepDelay)) %>%
  filter(Carrier %in% c("AA", "DL", "UA", "WN")) %>%
  mutate(late = case_when(
    DepDelay > 0 ~ "Yes",
    DepDelay <= 0 ~ "No"
      )
    ) %>% 
  group_by(Carrier, Month) %>%
  mutate(nflights = n()) %>%
  group_by(Carrier, Month, late) %>%
  mutate(
    nlate = n(),
    pct_late = (nlate / nflights) * 100) %>%
  filter(late == "Yes") %>%
  ungroup() %>%  
  select(Carrier, Month, pct_late) %>%
  distinct() %>%
  arrange(pct_late)
# Out:
#    Carrier Month pct_late
# 1  UA      9     17.85714
# 2  UA      2     18.58974
# 3  DL      9     20.19704
# 4  UA      5     20.22472
# 5  UA      4     20.42254
# 6  AA      9     21.40921
# 7  DL      2     21.52642
# 8  DL      8     22.52252
# 9  AA      2     23.05556
# 10 UA      3     23.31606
# 11 UA      8     24.15730
# 12 DL      3     25.23020
# 13 AA      8     26.63934
# 14 AA      4     28.28054
# 15 WN      2     29.13870
# 16 UA      6     29.34783
# 17 UA      1     30.18868
# 18 DL      4     30.32491
# 19 DL      1     30.41894
# 20 AA      3     30.86124
# 21 DL      5     30.97983
# 22 AA      5     32.35294
# 23 UA      7     32.47423
# 24 DL      6     32.97214
# 25 AA      6     33.60825
# 26 DL      7     33.67953
# 27 WN      1     34.03194
# 28 AA      1     34.36693
# 29 AA      7     35.40000
# 30 WN      9     36.20406
# 31 WN      4     36.68342
# 32 WN      3     38.39325
# 33 WN      5     44.20078
# 34 WN      8     48.96485
# 35 WN      6     49.66730
# 36 WN      7     49.81601

# %%
cmhflights %>%
    mutate(
      carrier_name = case_when(
          Carrier == "AA" ~ "American Airlines",
          Carrier == "DL" ~ "Delta Airlines",
          Carrier == "UA" ~ "United Airlines",
          Carrier == "EV" ~ "Express Jet",
          Carrier == "F9" ~ "Frontier Airlines",
          Carrier == "WN" ~ "Southwest Airlines",
          Carrier == "OO" ~ "SkyWest Airlines"
      )
  ) %>%
    select(Carrier, carrier_name) %>%
    group_by(Carrier, carrier_name) %>%
    tally()
# Out:
#   Carrier carrier_name       n
# 1 AA      American Airlines   3891
# 2 DL      Delta Airlines      5446
# 3 EV      Express Jet         3056
# 4 F9      Frontier Airlines   1568
# 5 OO      SkyWest Airlines    2041
# 6 UA      United Airlines     1527
# 7 WN      Southwest Airlines 18464

# %%
cmhflights %>%
  mutate(weekend = case_when(
    DayOfWeek %in% c(7, 1) ~ "Yes",
    TRUE ~ "No"
        )
    ) %>%
  select(DayOfWeek, weekend) %>%
  distinct()
# Out:
#   DayOfWeek weekend
# 1 7         Yes
# 2 1         Yes
# 3 2         No
# 4 3         No
# 5 4         No
# 6 5         No
# 7 6         No

# %%
read.table(
  'https://stats.idre.ucla.edu/stat/data/hsb2.csv',
  header = TRUE,
  sep = ","
  ) -> hsb2

# %%
hsb2 %>%
  mutate(
    female.f = case_when(
      female == 0 ~ "Male",
      female == 1 ~ "Female"),
    race.f = case_when(
      race == 1 ~ "Hispanic",
      race == 2 ~ "Asian",
      race == 3 ~ "African-American",
      TRUE ~ "White"),
    ses.f = case_when(
      ses == 1 ~ "Low",
      ses == 2 ~ "Medium",
      TRUE ~ "High"),
    schtyp.f = case_when(
      schtyp == 1 ~ "Public",
      TRUE ~ "Private"),
    prog.f = case_when(
      prog == 1 ~ "General",
      prog == 2 ~ "Academic",
      TRUE ~ "Vocational")
    ) -> hsb2

# %%
cmhflights %>%
  filter(Origin == "CMH") %>%
  count(Dest, sort = TRUE)
# Out:
#    Dest n
# 1  ATL  2884
# 2  MDW  1511
# 3  MCO  1148
# 4  DFW  1122
# 5  DEN   971
# 6  BWI   948
# 7  LAS   815
# 8  PHX   815
# 9  ORD   803
# 10 EWR   736
# 11 MSP   677
# 12 TPA   595
# 13 BNA   520
# 14 RSW   509
# 15 DCA   507
# 16 STL   495
# 17 DTW   485
# 18 LAX   483
# 19 BOS   475
# 20 IAH   460
# 21 DAL   273
# 22 OAK   273
# 23 FLL   240
# 24 LGA   173
# 25 PHL    57
# 26 MSY    22

# %%
cmhflights %>%
  filter(Origin == "CMH") %>%
  count(Carrier, Dest, sort = TRUE)
# Out:
#    Carrier Dest n
# 1  DL      ATL  2141
# 2  WN      MDW  1511
# 3  AA      DFW  1122
# 4  WN      BWI   948
# 5  WN      MCO   929
# 6  WN      ATL   743
# 7  EV      EWR   736
# 8  WN      TPA   595
# 9  UA      ORD   577
# 10 WN      LAS   542
# 11 AA      PHX   526
# 12 WN      BNA   520
# 13 WN      DCA   507
# 14 WN      STL   495
# 15 WN      RSW   486
# 16 WN      BOS   475
# 17 EV      IAH   458
# 18 OO      DTW   428
# 19 WN      DEN   384
# 20 DL      MSP   336
# 21 WN      PHX   289
# 22 F9      DEN   273
# 23 F9      LAS   273
# 24 WN      DAL   273
# 25 WN      OAK   273
# 26 OO      MSP   264
# 27 DL      LAX   242
# 28 AA      LAX   241
# 29 WN      FLL   240
# 30 F9      MCO   217
# 31 OO      ORD   199
# 32 UA      DEN   185
# 33 EV      LGA   173
# 34 OO      DEN   129
# 35 EV      MSP    77
# 36 AA      PHL    57
# 37 EV      DTW    55
# 38 EV      ORD    27
# 39 WN      MSY    22
# 40 F9      RSW    21
# 41 DL      DTW     2
# 42 DL      MCO     2
# 43 EV      RSW     2
# 44 OO      IAH     1
# 45 UA      IAH     1

# %%
cmhflights %>%
  summarise(n_distinct(TailNum))
# Out:
#   n_distinct(TailNum)
# 1 2248

# %%
cmhflights %>%
  group_by(Carrier) %>%
  summarise(num.flights = n_distinct(TailNum)) %>%
  arrange(-num.flights) %>% 
  top_n(4)
# Out:
# Selecting by num.flights
#   Carrier num.flights
# 1 WN      751
# 2 DL      539
# 3 UA      289
# 4 OO      222

# %%
cmhflights %>%
  filter(!is.na(TailNum)) %>% # Removing some missing cases 
  group_by(TailNum) %>%
  tally() %>% 
  arrange(-n) %>%
  top_n(4)
# Out:
# Selecting by n
#   TailNum n
# 1 N396SW  74
# 2 N601WN  66
# 3 N646SW  64
# 4 N635SW  62

# %%
tibble(
  Name = c("Tim", "Tammy", "Bubbles", "Panda"),
  Score = c(5, 8, 9, 10)
    ) -> df1

# %%
tibble(
  Name = c("Tim", "Tammy", "Bubbles"),
  Age = c(25, 78, 19)
    ) -> df2

# %%
tibble(
  Name = c("Tim", "Tammy", "Panda"),
  Education = c("BA", "PhD", "JD")
    ) -> df3

# %%
df1; df2; df3
# Out:
#   Name    Score
# 1 Tim      5
# 2 Tammy    8
# 3 Bubbles  9
# 4 Panda   10
#   Name    Age
# 1 Tim     25
# 2 Tammy   78
# 3 Bubbles 19
#   Name  Education
# 1 Tim   BA
# 2 Tammy PhD
# 3 Panda JD

# %%
df1 %>%
  full_join(df2, by = "Name") %>%
  full_join(df3, by = "Name")
# Out:
#   Name    Score Age Education
# 1 Tim      5    25  BA
# 2 Tammy    8    78  PhD
# 3 Bubbles  9    19  NA
# 4 Panda   10    NA  JD

# %%
df2 %>%
  left_join(df3, by = "Name")
# Out:
#   Name    Age Education
# 1 Tim     25  BA
# 2 Tammy   78  PhD
# 3 Bubbles 19  NA

# %%
df3 %>%
  left_join(df2, by = "Name")
# Out:
#   Name  Education Age
# 1 Tim   BA        25
# 2 Tammy PhD       78
# 3 Panda JD        NA

# %%
df2 %>%
  anti_join(df3, by = "Name")
# Out:
#   Name    Age
# 1 Bubbles 19

# %%
df3 %>%
  anti_join(df2, by = "Name")
# Out:
#   Name  Education
# 1 Panda JD

# %%
library(santoku)

cmhflights %>%
  mutate(
    depdelay_groups = chop_equally(DepDelay, groups = 4)
      ) %>%
  group_by(depdelay_groups) %>%
  tally()
# Out:
# Attaching package: ‘santoku’
# The following object is masked from ‘package:tidyr’:
#
#     chop
#   depdelay_groups n
# 1 [0%, 25%)        6887
# 2 [25%, 50%)       9267
# 3 [50%, 75%)      10143
# 4 [75%, 100%]      9225
# 5 NA                471

# %%
cmhflights %>%
  mutate(
    depdelay_groups = chop(DepDelay, breaks = c(0, 15, 30, 45))
      ) %>%
  group_by(depdelay_groups) %>%
  tally()
# Out:
#   depdelay_groups n
# 1 [-27, 0)        21108
# 2 [0, 15)          7883
# 3 [15, 30)         2567
# 4 [30, 45)         1240
# 5 [45, 1323]       2724
# 6 NA                471

# %%
cmhflights %>%
  filter(!is.na(DepDelay)) %>%
  mutate(
    depdelay_groups = chop_quantiles(
      DepDelay, c(0.2, 0.4, 0.6, 0.8)
    )
  ) %>%
  group_by(depdelay_groups) %>%
  tally()
# Out:
#   depdelay_groups n
# 1 [0%, 20%)       6887
# 2 [20%, 40%)      6342
# 3 [40%, 60%)      7879
# 4 [60%, 80%]      7362
# 5 (80%, 100%]     7052

# %%
cmhflights %>%
  filter(!is.na(DepDelay)) %>%
  mutate(
    depdelay_groups = chop_quantiles(
      DepDelay, seq(0.1, 0.9, by = 0.1)
    )
  ) %>%
  group_by(depdelay_groups) %>%
  tally()
# Out:
#    depdelay_groups n
# 1  [0%, 10%)       3006
# 2  [10%, 20%)      3881
# 3  [20%, 30%)      3344
# 4  [30%, 40%)      2998
# 5  [40%, 50%)      2925
# 6  [50%, 60%)      4954
# 7  [60%, 70%)      3262
# 8  [70%, 80%)      3773
# 9  [80%, 90%]      3904
# 10 (90%, 100%]     3475

# %%
cmhflights %>%
  filter(!is.na(DepDelay)) %>%
  mutate(
    depdelay_groups = chop_evenly(
        DepDelay,
        4
    )
  ) %>%
  group_by(depdelay_groups) %>%
  tally()
# Out:
#   depdelay_groups n
# 1 [-27, 310.5)    35439
# 2 [310.5, 648)       68
# 3 [648, 985.5)        5
# 4 [985.5, 1323]      10

# %%
tibble(
  response = c(
      rep("Agree", 25), 
      rep("Neutral", 30), 
      rep("Disagree", 45)
      )
    ) -> mydf

# %%
mydf %>%
  group_by(response) %>%
  tally()
# Out:
#   response n
# 1 Agree    25
# 2 Disagree 45
# 3 Neutral  30

# %%
mydf %>%
  mutate(
      ordered.response = ordered(
          response,
          levels = c("Agree", "Neutral", "Disagree")
      )
    ) %>%
  group_by(ordered.response) %>%
  tally()
# Out:
#   ordered.response n
# 1 Agree            25
# 2 Neutral          30
# 3 Disagree         45
